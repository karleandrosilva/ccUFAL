# %%
nomes = [None]*10
nomes
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %%
lucros = [5, 10, 11, 20, 1, -5, -10]

# %% [markdown]
# PARA SABER O MAIOR (função pronta)

# %%
max(lucros)
# Out:
# 20

# %%
def encontrar_maior(lista:list):
    maior = lista[0]
    for num in lista:
        if maior < num:
            maior = num
    return maior

# %%
encontrar_maior(lucros)
# Out:
# 20
