# %%
# ECINTRAR ELEMENTOS ABAIXO DA MEDIA

def abaixoMedia(lista):
    soma = 0
    abaixo = []
    for numero in lista:
        soma += numero
    media = soma / len(lista)

    for numero in lista:
        if numero < media:
            abaixo.append(numero)
    return abaixo

lista = [1, 2, 6, 5, 8, 10]
print(numero)
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[30], line 17
#
#      13
#
#      14     return abaixo
#
#      15
#
#      16 lista = [1, 2, 6, 5, 8, 10]
#
# ---> 17 print(abaixoMedia(numero))
#
#
#
# NameError: name 'numero' is not defined

# %%
# contar quantidade de elementos negativos

def contar_negativo(lista):
    cont  = 0
    for numero in lista: # tem que comparar todos
        if numero < 0:
            cont += 1
    return cont

lista = [50, -1, 3, -5, 11, -54, 14, -5, -9] #lista de inteiros
print(f'Elementos negativos:', contar_negativo(lista))
